# %% [markdown]
# # Subsetting data
# 1) Selecting(Columns)
# 2)Slicing (Rows)
# 3)Indexing (Selecting +Slicing)- through loc and iloc
# 4)Filtering (Selecting based on criteria)

# %%
## WORKING WITH DIRECTORIES
import os
os.getcwd()
os.chdir('C:\Users\DELL\Desktop')
# Out:
# 'C:\\Users\\DELL'

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\DELL\Desktop\EMERGING WOMEN\AB_NYC_2019.csv\AB_NYC_2019.csv")

# %%
data.sample(10)
# Out:
#              id                                               name    host_id  \
# 30316  23435040                      1 bd Apartment next to Subway   57292550
# 9152    7003788                        Luxury Apt 10mins Manhattan   21773199
# 42649  33110303        Cozy NYC Studio with Great Light & Comfort!   11776513
# 40651  31533898    TRENDi 6 BEDROOM  2 APARTMENTS COMBINED/12 BEDS  133234099
# 32692  25745458      Huge and beautiful 2BR in Greenpoint Brooklyn    2483350
# 17865  13997894       1 bedroom full apartment completely private!   83616984
# 8043    6198343                Calm airy top floor W'burgh 1.5 bed    1245722
# 37833  29946107  Spacious, sun-filled apartment in family townhome    3662048
# 45544  34817032                         Fantastic Midtown Elegance   94101463
# 31012  24042332  Beautiful sunlit spacious loft-like pvt. bedroom!   56917612
#
#       host_name neighbourhood_group     neighbourhood  latitude  longitude  \
# ...

# %%
data[data.price.between(10,20)]
# Out:
#              id                                           name    host_id  \
# 957      375249                Enjoy Staten Island Hospitality    1887999
# 2860    1620248  Large furnished 2 bedrooms- - 30 days Minimum    2196224
# 3950    2459916              $455 Cozy 1bd, BKLYN Sublet March   12577771
# 4647    3258197   Large 1br Duplex in Heart of Upper East Side   16477306
# 5542    4031809                  Prewar classic NYC apartment.   20902552
# ...         ...                                            ...        ...
# 47160  35612982      Luggage drop off ONLY! Close to LGA & JFK  108512889
# 47218  35642891                     Beautiful room in Bushwick  268138154
# 47979  36022650    Charming entire apartment in Hell's Kitchen    2967377
# 48486  36280646                   Cable and wfi, L/G included.  272872092
# 48832  36450814                       FLATBUSH HANG OUT AND GO  267223765
#
#          host_name neighbourhood_group       neighbourhood  latitude  \
# ...

# %%
data[data.price.isin(10,12,15,20)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-f7f67997bb49> in <module>
# ----> 1 data[data.price.isin(10,12,15,20)]
#
# TypeError: isin() takes 2 positional arguments but 5 were given

# %%
##Indexing (selecting +slicing)
data.id
data['id']
data[['id','name','neighbourhood']]
data.loc[[1,2,3,4,5,6,7],['id','name']]
data.iloc[[1,2,3,10],[0,1,5]]
# Out:
#       id                                 name    neighbourhood
# 1   2595                Skylit Midtown Castle          Midtown
# 2   3647  THE VILLAGE OF HARLEM....NEW YORK !           Harlem
# 3   3831      Cozy Entire Floor of Brownstone     Clinton Hill
# 10  5295     Beautiful 1br on Upper West Side  Upper West Side

# %%
##Filtering
data.query("price >80")
data[data.reviews_per_month.isna()]
data[~data.reviews_per_month.isna()]
# Out:
#              id                                              name    host_id  \
# 0          2539                Clean & quiet apt home by the park       2787
# 1          2595                             Skylit Midtown Castle       2845
# 3          3831                   Cozy Entire Floor of Brownstone       4869
# 4          5022  Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099         Large Cozy 1 BR Apartment In Midtown East       7322
# ...         ...                                               ...        ...
# 48782  36425863        Lovely Privet Bedroom with Privet Restroom   83554966
# 48790  36427429                          No.2 with queen size bed  257683179
# 48799  36438336                                   Seas The Moment  211644523
# 48805  36442252                     1B-1B apartment near by Metro  273841667
# 48852  36455809           Cozy Private Room in Bushwick, Brooklyn   74162901
#
# ...

# %%
#String filtering - IMP
#substring filtering using startswith, endswith and contains
#data[data.neighbourhood_group.str.contains("Manhattan")]
#data[data.neighbourhood_group.str.startswith("Brook")]
data[data.host_name.isin(['Jennifer','Laura'])]
#data[data.host_name.str.istitle()]
# Out:
#              id                                               name    host_id  \
# 1          2595                              Skylit Midtown Castle       2845
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 48        13050                          bright and stylish duplex      50846
# 306       71248                Bright and lovely 1 bdrm apt in LES     363834
# 326       80493                  Cozy room in East Village with AC     434987
# ...         ...                                                ...        ...
# 48144  36108534  Luxury 1 bed in UWS Finest Building with Gym #...  116305897
# 48155  36109805           Amazing Studio in the UWS with Gym #6108  116305897
# 48164  36113257                                       WaHi Walk Up   22528598
# 48511  36304817  HugeHipHome 5BR 2 Bath w/ Yard 15 min to Midtown!  143725634
# 48853  36455917     Sunny&quiet paradise in the WV with open views  274103383
#
# ...

# %%
#order by equivalent of SQL
data_order=data.sort_values('host_id',ascending='False')
data_order.head(100)
# Out:
#              id                                               name  host_id  \
# 30604  23669201  Great Price: Williamsburg Brooklyn Loft off L ...     2438
# 2290    1101224                                         THE PUTNAM     2571
# 0          2539                 Clean & quiet apt home by the park     2787
# 13963  10593675  La Spezia room.  Clean, quiet and comfortable bed     2787
# 13583  10160215                               Torre del Lago Room.     2787
# ...         ...                                                ...      ...
# 19         7750                  Huge 2 BR Upper East  Cental Park    17985
# 3315    1980179            Best of the East Village Cozy 2 Bedroom    18174
# 12978   9855876                  Large Room in LES ($80-100/night)    18282
# 26553  21135737       Clean Comfortable Apartment near the Subway!    18283
# 16413  13182297            Sculptor's Light-filled Loft (Bushwick)    18742
#
# ...

# %% [markdown]
# ## Dataframe Info

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
data.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %%
data.sample(30)
# Out:
#              id                                               name    host_id  \
# 17695  13895437        Bushwick Basement Large Room with Half Bath    2776152
# 46099  35079012                     Amazing Williamsburg Apartment    1722490
# 36886  29320258                     Private Room in Prime Bushwick   89339003
# 40747  31626307                Bright and Airy Freeman Street loft     513839
# 48428  36262925     Amazing 1BR Apartment near Columbia University    6186588
# 45931  35004930                      Furnished Apartment in Queens  236530772
# 111       26520       Cozy Room #3, Landmark Home 1 Block to PRATT      51038
# 17336  13686914              Murray Hill/Midtown East Flex Bedroom   28250527
# 34195  27127722           Suite 18 - Cozy room w/ Private Bathroom   99296570
# 36203  28784880       *PRIVATE* Loft 5 minutes away from LaGuardia   65671256
# 26005  20760187                        Warm Duplex in a Brownstone    9663247
# ...

# %%
#data.T
# Out:
#                                                              0      \
# id                                                            2539
# name                            Clean & quiet apt home by the park
# host_id                                                       2787
# host_name                                                     John
# neighbourhood_group                                       Brooklyn
# neighbourhood                                           Kensington
# latitude                                                   40.6475
# longitude                                                 -73.9724
# room_type                                             Private room
# price                                                          149
# minimum_nights                                                   1
# number_of_reviews                                                9
# last_review                                             2018-10-19
# ...

# %%
data.shape
# Out:
# (48895, 16)

# %%
len(data)
# Out:
# 48895

# %%
data.mean()
data.std()
# Out:
# id                                1.098311e+07
# host_id                           7.861097e+07
# latitude                          5.453008e-02
# longitude                         4.615674e-02
# price                             2.401542e+02
# minimum_nights                    2.051055e+01
# number_of_reviews                 4.455058e+01
# reviews_per_month                 1.680442e+00
# calculated_host_listings_count    3.295252e+01
# availability_365                  1.316223e+02
# dtype: float64

# %%
data.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
data.room_type.unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
data.room_type.nunique()
# Out:
# 3

# %%
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=48895, step=1)

# %%
data.iloc[1,:]
# Out:
# id                                                 2595
# name                              Skylit Midtown Castle
# host_id                                            2845
# host_name                                      Jennifer
# neighbourhood_group                           Manhattan
# neighbourhood                                   Midtown
# latitude                                        40.7536
# longitude                                      -73.9838
# room_type                               Entire home/apt
# price                                               225
# minimum_nights                                        1
# number_of_reviews                                    45
# last_review                                  2019-05-21
# reviews_per_month                                  0.38
# calculated_host_listings_count                        2
# availability_365                                    355
# Name: 1, dtype: object
